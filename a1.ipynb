# %% [markdown]
# # Aufgabe 1
#
# ## a)
# $$C = 4$$
# $$n_0 = 4$$
#
# ## b)
# $$C = 4$$
# $$n_0 = 2$$

# %% [markdown]
# # Aufgabe 2
# ## a)
# Ja, weil Exponentialfunktionen immer schneller wachsen als Polynome.
#
# ## b)
# $ 10^{\log n} = n $, gilt also auch, weil Polynome immer langsamer wachsen als Exponentialfunktionen.
#
# ## c)
#
# $$ 10^{\sqrt{n}} = {(2^{\log_2 10})}^{\sqrt{n}} = 2^{\log_2 10 \cdot \sqrt{n}}$$
#
# Da $\sqrt{n}$ immer langsamer wächst als $n$ gilt die Aussage.
#
# ## d)
#
# Gilt nicht, weil im Endeffekt $\log_2 10 \cdot n$ immer schneller wächst als $n$.

# %% [markdown]
# # Aufgabe 3

# %%
from math import log2,log10,log
lengths =[1*(10** i)for i in range(5,10)]
fast_slow =[print((i**2)/(1*(10**8))) for i in lengths]
print()
slow_fast =[print((i * log10(i))/(1*(10**5))) for i in lengths]
# Out:
# 100.0
# 10000.0
# 1000000.0
# 100000000.0
# 10000000000.0
#
# 5.0
# 60.0
# 700.0
# 8000.0
# 90000.0

# %% [markdown]
# # Aufgabe 4

# %%
size =[10,20,50,100,200,1000]
time =[print((2**i)*(50*10**-12)) for i in size]

print()

size =[50,100,200,1000,5000]
time =[print((2** i)*(50*10**-18)*(20**-1*10**-9)) for i in size]
# Out:
# 5.12e-08
# 5.24288e-05
# 56294.9953421312
# 6.338253001141147e+19
# 8.034690221294952e+49
# 5.357543035931337e+290
#
# 2.814749767106561e-12
# 3169.1265005705745
# 4.017345110647477e+33
# 2.678771517965669e+274
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipykernel_40301/4175607510.py in <module>
#       5
#       6 size =[50,100,200,1000,5000]
# ----> 7 time =[print((2** i)*(50*10**-18)*(20**-1*10**-9)) for i in size]
#
# /tmp/ipykernel_40301/4175607510.py in <listcomp>(.0)
#       5
#       6 size =[50,100,200,1000,5000]
# ----> 7 time =[print((2** i)*(50*10**-18)*(20**-1*10**-9)) for i in size]
#
# OverflowError: int too large to convert to float
